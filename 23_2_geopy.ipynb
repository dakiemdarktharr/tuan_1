# %%
# !pip install folium geopy

# %%
import folium
from geopy.distance import geodesic



trung_tam = [10.760205, 106.666115]
m = folium.Map(location=trung_tam, zoom_start=14)




folium.Marker(location=trung_tam, popup="UEH csb", icon=folium.Icon(color='red', icon='star', prefix='fa')).add_to(m)
p1 = [10.758800, 106.661700]
khoang_cach1 = geodesic(trung_tam, p1).km
folium.Marker(location=p1, popup=f"Sân vận động Thống Nhất {round(khoang_cach1, 2)} km", icon=folium.Icon(color='blue', icon='info-sign')).add_to(m)
folium.PolyLine(locations=[trung_tam, p1], color="gray", dash_array='5, 5').add_to(m)
p2 = [10.755240, 106.664471]
khoang_cach2 = geodesic(trung_tam, p2).km
folium.Marker(location=p2, popup=f"Bệnh viện Đại học Y Dược {round(khoang_cach2, 2)} km", icon=folium.Icon(color='blue', icon='info-sign')).add_to(m)
folium.PolyLine(locations=[trung_tam, p2], color="gray", dash_array='5, 5').add_to(m)
p3 = [10.757800, 106.659500]
khoang_cach3 = geodesic(trung_tam, p3).km
folium.Marker(location=p3, popup=f"Bệnh viện Chợ Rẫy {round(khoang_cach3, 2)} km", icon=folium.Icon(color='blue', icon='info-sign')).add_to(m)
folium.PolyLine(locations=[trung_tam, p3], color="gray", dash_array='5, 5').add_to(m)
p4 = [10.755500, 106.659300]
khoang_cach4 = geodesic(trung_tam, p4).km
folium.Marker(location=p4, popup=f"The Garden Mall {round(khoang_cach4, 2)} km", icon=folium.Icon(color='blue', icon='info-sign')).add_to(m)
folium.PolyLine(locations=[trung_tam, p4], color="gray", dash_array='5, 5').add_to(m)
p5 = [10.764200, 106.668500]
khoang_cach5 = geodesic(trung_tam, p5).km
folium.Marker(location=p5, popup=f"Chùa Ấn Quang {round(khoang_cach5, 2)} km", icon=folium.Icon(color='blue', icon='info-sign')).add_to(m)
folium.PolyLine(locations=[trung_tam, p5], color="gray", dash_array='5, 5').add_to(m)
p6 = [10.760500, 106.661500]
khoang_cach6 = geodesic(trung_tam, p6).km
folium.Marker(location=p6, popup=f"Chợ Nhật Tảo {round(khoang_cach6, 2)} km", icon=folium.Icon(color='blue', icon='info-sign')).add_to(m)
folium.PolyLine(locations=[trung_tam, p6], color="gray", dash_array='5, 5').add_to(m)
p7 = [10.764500, 106.674000]
khoang_cach7 = geodesic(trung_tam, p7).km
folium.Marker(location=p7, popup=f"Trường THPT chuyên Lê Hồng Phong {round(khoang_cach7, 2)} km", icon=folium.Icon(color='blue', icon='info-sign')).add_to(m)
folium.PolyLine(locations=[trung_tam, p7], color="gray", dash_array='5, 5').add_to(m)
p8 = [10.756200, 106.663500]
khoang_cach8 = geodesic(trung_tam, p8).km
folium.Marker(location=p8, popup=f"Công viên Văn hóa Hùng Vương {round(khoang_cach8, 2)} km", icon=folium.Icon(color='blue', icon='info-sign')).add_to(m)
folium.PolyLine(locations=[trung_tam, p8], color="gray", dash_array='5, 5').add_to(m)
p9 = [10.763500, 106.661200]
khoang_cach9 = geodesic(trung_tam, p9).km
folium.Marker(location=p9, popup=f"Co.opmart Lý Thường Kiệt {round(khoang_cach9, 2)} km", icon=folium.Icon(color='blue', icon='info-sign')).add_to(m)
folium.PolyLine(locations=[trung_tam, p9], color="gray", dash_array='5, 5').add_to(m)
p10 = [10.766500, 106.671500]
khoang_cach10 = geodesic(trung_tam, p10).km
folium.Marker(location=p10, popup=f"Bệnh viện Nhi Đồng 1 {round(khoang_cach10, 2)} km", icon=folium.Icon(color='blue', icon='info-sign')).add_to(m)
folium.PolyLine(locations=[trung_tam, p10], color="gray", dash_array='5, 5').add_to(m)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...
